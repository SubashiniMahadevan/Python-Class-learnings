# %% [markdown]
# **Import the Sales data**

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-4836e125-1fe9-4cd9-be34-780a8d985e41" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-4836e125-1fe9-4cd9-be34-780a8d985e41">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# **Display the information about the dataframe**

# %%
#Working with sales data
import pandas as pd
#importing data as csv
d1 = pd.read_csv('sales.csv')
d1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23 entries, 0 to 22
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Market        23 non-null     object
#  1   Region        23 non-null     object
#  2   No_of_Orders  23 non-null     int64
#  3   Profit        23 non-null     object
#  4   Sales         23 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.0+ KB

# %% [markdown]
# **Checking for Missing values**

# %%
#checking for missing values
d1.isnull()
d1.isnull().sum()
# Out:
# Market          0
# Region          0
# No_of_Orders    0
# Profit          0
# Sales           0
# dtype: int64

# %% [markdown]
# **Set the first two columns as index**

# %%
colindex = ['Market','Region']
df = pd.DataFrame(d1).set_index(colindex)

# %% [markdown]
# **Display first 3 land last 3 rows of the sales dataframe**

# %%
df.head(3)
# Out:
#                         No_of_Orders      Profit      Sales
# Market Region
# Africa Western Africa            251  -12,901.51  78,476.06
#        Southern Africa            85   11,768.58  51,319.50
#        North Africa              182   21,643.08  86,698.89

# %%
df.tail(3)
# Out:
#                    No_of_Orders     Profit       Sales
# Market Region
# USCA   Eastern US           443  47,462.04  264,973.98
#        Central US           356  33,697.43  170,416.31
#        Canada                49   7,246.62   26,298.81

# %% [markdown]
# **Display the statistical information about the dataframe**

# %%
#Statistics Library
df.describe()
# Out:
#        No_of_Orders
# count     23.000000
# mean     366.478261
# std      246.590361
# min       37.000000
# 25%      211.500000
# 50%      356.000000
# 75%      479.500000
# max      964.000000

# %% [markdown]
# **Display the sales column as a series**

# %%
#Creating a series for Sales data alone
data1 = df['Sales']
series1 = pd.Series(data1)
series1
# Out:
# Market        Region
# Africa        Western Africa        78,476.06
#               Southern Africa       51,319.50
#               North Africa          86,698.89
#               Eastern Africa        44,182.60
#               Central Africa        61,689.99
# Asia Pacific  Western Asia         124,312.24
#               Southern Asia        351,806.60
#               Southeastern Asia    329,751.38
#               Oceania              408,002.98
#               Eastern Asia         315,390.77
#               Central Asia           8,190.74
# Europe        Western Europe       656,637.14
#               Southern Europe      215,703.93
#               Northern Europe      252,969.09
#               Eastern Europe       108,258.93
# LATAM         South America        210,710.49
#               Central America      461,670.28
#               Caribbean            116,333.05
# USCA          Western US           251,991.83
#               Southern US          148,771.91
# ...

# %% [markdown]
# **Display sales and profit column as a dataframe**

# %%
#creating a dataframe with market and region as index and profit and sales as columns
columns = ['Profit','Sales']
df1 = pd.DataFrame(df[columns])
df1
# Out:
#                                     Profit       Sales
# Market       Region
# Africa       Western Africa     -12,901.51   78,476.06
#              Southern Africa     11,768.58   51,319.50
#              North Africa        21,643.08   86,698.89
#              Eastern Africa       8,013.04   44,182.60
#              Central Africa      15,606.30   61,689.99
# Asia Pacific Western Asia       -16,766.90  124,312.24
#              Southern Asia       67,998.76  351,806.60
#              Southeastern Asia   20,948.84  329,751.38
#              Oceania             54,734.02  408,002.98
#              Eastern Asia        72,805.10  315,390.77
#              Central Asia        -2,649.76    8,190.74
# Europe       Western Europe      82,091.27  656,637.14
#              Southern Europe     18,911.49  215,703.93
#              Northern Europe     43,237.44  252,969.09
#              Eastern Europe      25,050.69  108,258.93
# LATAM        South America       12,377.59  210,710.49
# ...

# %% [markdown]
# **Display the data for Southern Asia**

# %%
df1.loc['Asia Pacific','Southern Asia']
# Out:
# Profit     67,998.76
# Sales     351,806.60
# Name: (Asia Pacific, Southern Asia), dtype: object

# %% [markdown]
# **Display Sales and Profit data for Western Africa, Southern Africa, and North Africa**

# %%
a1= 'Africa',"Western Africa"
b1 = 'Africa',"Southern Africa"
c1 = 'Africa',"North Africa"
df1.loc[[a1,b1,c1]]
# Out:
#                             Profit      Sales
# Market Region
# Africa Western Africa   -12,901.51  78,476.06
#        Southern Africa   11,768.58  51,319.50
#        North Africa      21,643.08  86,698.89

# %% [markdown]
# **Display Markets with Sales above 300,000**

# %%
df1['Sales'] = df['Sales'].str.replace(',', '').astype(float)
condn = (df1['Sales'] > 300000.00)
df1[condn]
# Out:
#                                    Profit      Sales
# Market       Region
# Asia Pacific Southern Asia      67,998.76  351806.60
#              Southeastern Asia  20,948.84  329751.38
#              Oceania            54,734.02  408002.98
#              Eastern Asia       72,805.10  315390.77
# Europe       Western Europe     82,091.27  656637.14
# LATAM        Central America    74,679.54  461670.28
