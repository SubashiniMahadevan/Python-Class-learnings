# %% [markdown]
# **Import the file named Data_Analyst_Sample.csv in Pandas**

# %%
from google.colab import files
uploaded =files.upload()
# Out:
#      <input type="file" id="files-0cf4461d-e92c-46d9-98cc-d37a4119e21d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-0cf4461d-e92c-46d9-98cc-d37a4119e21d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_csv('Data_Analyst_Sample.csv')
df
# Out:
#                                            Campaign Name  Campaign ID  \
# 0      CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# 1      CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# 2      CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# 3      CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# 4      CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# ...                                                  ...          ...
# 52476  CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDispla...     25362071
# 52477  CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDispla...     25362071
# 52478  CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDispla...     25362071
# 52479  CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Pr...     25362071
# 52480  CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticVideo_...     24922332
#
#                                                Placement        Date  \
# ...

# %% [markdown]
# **Explore the file with at least 3 common exploration methods in Pandas**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52481 entries, 0 to 52480
# Data columns (total 10 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Campaign Name             52445 non-null  object
#  1   Campaign ID               52481 non-null  int64
#  2   Placement                 52481 non-null  object
#  3   Date                      52448 non-null  object
#  4   Impressions               52451 non-null  float64
#  5   Clicks                    52481 non-null  int64
#  6   Cost                      52458 non-null  float64
#  7   Video Completions         52481 non-null  int64
#  8   Find A Dealer Conversion  52481 non-null  int64
#  9   Online Brochure Download  52481 non-null  int64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 4.0+ MB

# %%
df.loc[df.isna().any(axis="columns")]
# Out:
#                                            Campaign Name  Campaign ID  \
# 9      CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# 11     CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDi...     25347887
# 16                                                   NaN     25347887
# 20                                                   NaN     25347887
# 22     CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisp...     25347887
# ...                                                  ...          ...
# 49332  CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVi...     25336315
# 49333  CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVi...     25336315
# 49334  CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVi...     25336315
# 50525  CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVi...     25336315
# 50526  CY21_Q1_LOC_ES_C-Class_Mercedes_ProgrammaticVi...     25336315
#
#                                                Placement        Date  \
# ...

# %%
pd.isna(df)
# Out:
#        Campaign Name  Campaign ID  Placement   Date  Impressions  Clicks  \
# 0              False        False      False  False        False   False
# 1              False        False      False  False        False   False
# 2              False        False      False  False        False   False
# 3              False        False      False  False        False   False
# 4              False        False      False  False        False   False
# ...              ...          ...        ...    ...          ...     ...
# 52476          False        False      False  False        False   False
# 52477          False        False      False  False        False   False
# 52478          False        False      False  False        False   False
# 52479          False        False      False  False        False   False
# 52480          False        False      False  False        False   False
#
#         Cost  Video Completions  Find A Dealer Conversion  \
# ...

# %%
df.isnull().values.any(axis = 1)
# Out:
# array([False, False, False, ..., False, False, False])

# %% [markdown]
# **Remove missing values from columns that contain Pandas object datatype**

# %%
df1 =df.copy()
df1.dropna(subset = ['Campaign Name','Date'],inplace = True)

# %% [markdown]
# **Replace missing values by zero in columns that contain numbers**

# %%
df1['Cost'].fillna(0,inplace = True)
df1['Impressions'].fillna(0,inplace =True)

# %% [markdown]
# **Verify that no missing values are in the data file**

# %%
df1.isnull().values.any(axis = 1)
# Out:
# array([False, False, False, ..., False, False, False])

# %%
df1.isnull().sum()
# Out:
# Campaign Name               0
# Campaign ID                 0
# Placement                   0
# Date                        0
# Impressions                 0
# Clicks                      0
# Cost                        0
# Video Completions           0
# Find A Dealer Conversion    0
# Online Brochure Download    0
# dtype: int64

# %% [markdown]
# **Count how many errors there are in the dataset**

# %%
df1['Campaign Name'].str.contains("CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting").sum()
# Out:
# 9

# %% [markdown]
# **Use the .replace() method to correct the errors. Verify the errors have been corrected**

# %%
df1.replace('CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting','CY21_Q1_LOC_BE_Mercedes_S-Class_ProgrammaticDisplay_Prospecting',inplace = True)
df1.replace('CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prosp','CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prospecting',inplace =True)
df1.replace('CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Prospecting','CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDisplay_Prospecting',inplace = True)
df1.replace('CY21_Q1_LOC_FR_Merc_C-Class_ProgrammaticVideo_Prospecting','CY21_Q1_LOC_FR_Mercedes_C-Class_ProgrammaticVideo_Prospecting', inplace = True)
df1["Campaign Name"].str.contains("CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting").sum()
df1["Campaign Name"].str.contains("CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prosp").sum()

#checking for errors

df1[df1["Campaign Name"] == "CY21_Q1_LOC_BE_Mercedes_S-Cla_ProgrammaticDisplay_Prospecting"]
df1[df1["Campaign Name"] == "CY21_Q1_LOC_BE_Smart_Fortwo_ProgrammaticVideo_Prosp"]
df1[df1["Campaign Name"] == "CY21_Q1_LOC_ES_Smart_Fortwo_ProgrammaticDis_Prospecting"]
df1[df1["Campaign Name"] == "CY21_Q1_LOC_FR_Merc_C-Class_ProgrammaticVideo_Prospecting"]
# Out:
# Empty DataFrame
# Columns: [Campaign Name, Campaign ID, Placement, Date, Impressions, Clicks, Cost, Video Completions, Find A Dealer Conversion, Online Brochure Download]
# Index: []
